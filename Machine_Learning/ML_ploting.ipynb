# %%
import numpy as np
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
x = np.linspace(-2, -0.5, 300), np.linspace(0.5, 2, 300)
y = np.linspace(-2, -0.5, 300), np.linspace(0.5, 2, 300)

X, Y = np.meshgrid(x, y)
def f(x, y):
    return x**2 + y **2 + x**(-2) * y **(-2)


def f1(x, y):
    return 3*x - x**3 -2*(y**2) + y**4

def f2(x, y):
    return x**2 + y**4 + 2*x*y

def Plot(z):
    #plt.style.use('ggplot')
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    ax.contour3D(X, Y, z, 50, cmap='binary')
    ax.view_init(250, 50)
    fig

# z1 = f1(X, Y)
# Plot(z1)

z = f2(X, Y)
print(np.min(z), np.max(z))
Plot(z)
# Out:
# -0.2499959687089669 28.0
